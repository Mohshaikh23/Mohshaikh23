# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_json('Repos/repositories.json')
df.shape
# Out:
# (26, 79)

# %%
df.columns
# Out:
# Index(['id', 'node_id', 'name', 'full_name', 'private', 'owner', 'html_url',
#        'description', 'fork', 'url', 'forks_url', 'keys_url',
#        'collaborators_url', 'teams_url', 'hooks_url', 'issue_events_url',
#        'events_url', 'assignees_url', 'branches_url', 'tags_url', 'blobs_url',
#        'git_tags_url', 'git_refs_url', 'trees_url', 'statuses_url',
#        'languages_url', 'stargazers_url', 'contributors_url',
#        'subscribers_url', 'subscription_url', 'commits_url', 'git_commits_url',
#        'comments_url', 'issue_comment_url', 'contents_url', 'compare_url',
#        'merges_url', 'archive_url', 'downloads_url', 'issues_url', 'pulls_url',
#        'milestones_url', 'notifications_url', 'labels_url', 'releases_url',
#        'deployments_url', 'created_at', 'updated_at', 'pushed_at', 'git_url',
#        'ssh_url', 'clone_url', 'svn_url', 'homepage', 'size',
#        'stargazers_count', 'watchers_count', 'language', 'has_issues',
#        'has_projects', 'has_downloads', 'has_wiki', 'has_pages',
#        'has_discussions', 'forks_count', 'mirror_url', 'archived', 'disabled',
#        'open_issues_count', 'license', 'allow_forking', 'is_template',
#        'web_commit_signoff_required', 'topics', 'visibility', 'forks',
#        'open_issues', 'watchers', 'default_branch'],
#       dtype='object')

# %%
df.owner[0]
# Out:
# {'login': 'Mohshaikh23',
#  'id': 93477768,
#  'node_id': 'U_kgDOBZJbiA',
#  'avatar_url': 'https://avatars.githubusercontent.com/u/93477768?v=4',
#  'gravatar_id': '',
#  'url': 'https://api.github.com/users/Mohshaikh23',
#  'html_url': 'https://github.com/Mohshaikh23',
#  'followers_url': 'https://api.github.com/users/Mohshaikh23/followers',
#  'following_url': 'https://api.github.com/users/Mohshaikh23/following{/other_user}',
#  'gists_url': 'https://api.github.com/users/Mohshaikh23/gists{/gist_id}',
#  'starred_url': 'https://api.github.com/users/Mohshaikh23/starred{/owner}{/repo}',
#  'subscriptions_url': 'https://api.github.com/users/Mohshaikh23/subscriptions',
#  'organizations_url': 'https://api.github.com/users/Mohshaikh23/orgs',
#  'repos_url': 'https://api.github.com/users/Mohshaikh23/repos',
#  'events_url': 'https://api.github.com/users/Mohshaikh23/events{/privacy}',
#  'received_events_url': 'https://api.github.com/users/Mohshaikh23/received_events',
#  'type': 'User',
#  'site_admin': False}

# %%
new_df = df[['name', 'html_url','description', 'topics']]

# %%
tags = {
    "machine_learning": ["machine-learning", "ml"],
    "deep_learning": ["deep-learning", "dl"],
    "nlp": ["nlp", "natural-language-processing"],
    "generative_ai": ["generative-ai"],
    "computer_vision": ["computer-vision", "cv"],
    "python_project": ["python-project", "general"]
}

def classify_tags(dataframe, column):
    classification = []
    for value_list in dataframe[column]:
        category_found = False
        for value in value_list:
            for key, value_list in tags.items():
                if value in value_list:
                    classification.append(key)
                    category_found = True
                    break
            if category_found:
                break
        else:
            classification.append("Unclassified")
    return classification

# Example usage
classification = classify_tags(new_df, "topics")
new_df["Classification"] = classification

new_df
# Out:
# C:\Users\mohsi\AppData\Local\Temp\ipykernel_14852\2118726646.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df["Classification"] = classification
#                               name  \
# 0               bostonhousepricing
# 1   Chicken-Disease-Classification
# 2                Color_Picker_Draw
# 3                   Customer_Churn
# 4       Diabetes-Prediction-Model-
# 5                 Document_Scanner
# 6                         EASY_OCR
# 7             Eyes-Detection-Model
# 8    Face-Recognition-using-OPENCV
# 9            Flipkart_Webscrapping
# 10                      Langchain_
# 11         Loan-Status-Prediction-
# 12                     MCM-Project
# 13                     Mohshaikh23
# 14     MOVIE-RECOMMENDATION-SYSTEM
# 15     Multiple-Disease-Prediction
# 16                        News_GUI
# 17         Number_Plate_Recognizer
# 18                  Object-Tracker
# 19     Sonar-Rock-Mine-Predictions
# 20                 Spell_Corrector
# 21               starter-micro-api
# 22        Superstore-Excel-Project
# 23                 Text-Summarizer
# 24                 Voice-Assistant
# 25          whatsapp-chat-analyzer
#
#                                              html_url  \
# 0   https://github.com/Mohshaikh23/bostonhousepricing
# 1   https://github.com/Mohshaikh23/Chicken-Disease...
# 2    https://github.com/Mohshaikh23/Color_Picker_Draw
# 3       https://github.com/Mohshaikh23/Customer_Churn
# 4   https://github.com/Mohshaikh23/Diabetes-Predic...
# 5     https://github.com/Mohshaikh23/Document_Scanner
# 6             https://github.com/Mohshaikh23/EASY_OCR
# 7   https://github.com/Mohshaikh23/Eyes-Detection-...
# 8   https://github.com/Mohshaikh23/Face-Recognitio...
# 9   https://github.com/Mohshaikh23/Flipkart_Webscr...
# 10          https://github.com/Mohshaikh23/Langchain_
# 11  https://github.com/Mohshaikh23/Loan-Status-Pre...
# 12         https://github.com/Mohshaikh23/MCM-Project
# 13         https://github.com/Mohshaikh23/Mohshaikh23
# 14  https://github.com/Mohshaikh23/MOVIE-RECOMMEND...
# 15  https://github.com/Mohshaikh23/Multiple-Diseas...
# 16            https://github.com/Mohshaikh23/News_GUI
# 17  https://github.com/Mohshaikh23/Number_Plate_Re...
# 18      https://github.com/Mohshaikh23/Object-Tracker
# 19  https://github.com/Mohshaikh23/Sonar-Rock-Mine...
# 20     https://github.com/Mohshaikh23/Spell_Corrector
# 21   https://github.com/Mohshaikh23/starter-micro-api
# 22  https://github.com/Mohshaikh23/Superstore-Exce...
# 23     https://github.com/Mohshaikh23/Text-Summarizer
# 24     https://github.com/Mohshaikh23/Voice-Assistant
# 25  https://github.com/Mohshaikh23/whatsapp-chat-a...
#
#                                           description  \
# 0                                                None
# 1   The chicken disease classification project aim...
# 2   using OPENCV to create a color picker and usin...
# 3                                     Customer Churn
# 4          Diabetes Prediction Model  using SVM Model
# 5    Realtime Document Scanner using OpenCV on Camera
# 6            Text Detection From Images Using EasyOCR
# 7                   Eye Detection using Haar Cascades
# 8        The process of face recognition using OpenCV
# 9                         Scraping data from Flipkart
# 10  Stepping into LLM Models and its versatile fun...
# 11  Model Building using SVM for Loan Prediction u...
# 12                     MCM Occupancy Data with Report
# 13                Config files for my GitHub profile.
# 14  Up to 5000 Movies scrutinized for you and face...
# 15                        Detecting multiple disease
# 16                       News Viewer GUI with Tkinter
# 17  Detects number Plate and stores it in a scanne...
# 18  Detecting Object as position changes using OPENCV
# 19  Sonar data for Rock V/S Mine Prediction using ...
# 20  Spell checking, correcting and giving meaning ...
# 21                                               None
# 22  a superstore discrete data consisting of numer...
# 23   tool or algorithm that aims to condense a lon...
# 24         Voice Assistant named Jarvis with OPEN AI
# 25  All whatsapp chats analyzed and shown in form ...
#
#                                                topics    Classification
# 0                                  [machine-learning]  machine_learning
# 1   [deep-learning, dvc, flask, flask-cors, joblib...     deep_learning
# 2   [camera, color, computer-vision, contour-detec...   computer_vision
# 3   [churn-prediction, customer, data, data-scienc...  machine_learning
# 4                                  [machine-learning]  machine_learning
# 5                                   [computer-vision]   computer_vision
# 6   [computer-vision, easyocr-library, matplotlib,...   computer_vision
# 7                                   [computer-vision]   computer_vision
# 8                                   [computer-vision]   computer_vision
# 9   [beautifulsoup, flipkart-scraper-python, panda...    python_project
# 10                                              [nlp]               nlp
# 11                                 [machine-learning]  machine_learning
# 12                                   [python-project]    python_project
# 13                    [config, github-config, resume]      Unclassified
# 14           [machine-learning, movie-recommendation]  machine_learning
# 15  [diabetes, disease-prediction, heart, logistic...  machine_learning
# 16                                   [python-project]    python_project
# 17                                  [computer-vision]   computer_vision
# 18                          [computer-vision, opencv]   computer_vision
# 19                                 [machine-learning]  machine_learning
# 20  [gingerit-library, nlp, pandas, spellcheck, sp...               nlp
# 21                                                 []      Unclassified
# 22                                                 []      Unclassified
# 23  [boto3, datasets, ensure, fastapi, jinja2, mat...               nlp
# 24                                              [nlp]               nlp
# 25  [chat, jupyter-notebook, machine-learning, nlp...  machine_learning
